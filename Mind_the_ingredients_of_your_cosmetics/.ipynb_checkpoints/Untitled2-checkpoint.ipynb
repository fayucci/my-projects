# %%
import pandas as pd
import re

# %%
df = pd.read_csv('datasets/cosmetic_filter_COPY.csv')

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 13'], axis=1)

# %%
df['ingredients'] = df['ingredients'].str.replace(r'\.+$', '', regex=True)

# %%
display(df)
# Out:
#             label                          brand  \
# 0     Moisturizer                         LA MER
# 1     Moisturizer                          SK-II
# 2     Moisturizer                 DRUNK ELEPHANT
# 3     Moisturizer                         LA MER
# 4     Moisturizer                   IT COSMETICS
# ...           ...                            ...
# 1265  Sun protect                KATE SOMERVILLE
# 1266  Sun protect                         KORRES
# 1267  Sun protect                KATE SOMERVILLE
# 1268  Sun protect                  VITA LIBERATA
# 1269  Sun protect  ST. TROPEZ TANNING ESSENTIALS
#
#                                                    name  price  rank  \
# 0                                       Crème de la Mer    175   4.1
# 1                              Facial Treatment Essence    179   4.1
# 2                            Protini™ Polypeptide Cream     68   4.4
# 3                           The Moisturizing Soft Cream    175   3.8
# ...

# %%
#corpus = [ingredients.lower().split(', ') for ingredients in df['ingredients']]
corpus = [re.split('\s*,\s+', ingredients.lower()) for ingredients in df['ingredients']]
all_ingre = (ingredient for ingredients in corpus for ingredient in ingredients)

unique_ingr = list(dict.fromkeys(all_ingre))

ingre_tupla = [(i, ingre) for ingre, i in enumerate(unique_ingr)]
    
ingredient_idx = dict(ingre_tupla)

# %%
display(sorted(unique_ingr))
# Out:
# ['',
#  ' 2% salicylic acid (bha)',
#  ' acrylate crosspolymer',
#  ' acrylates/c1030 alkyl acrylate crosspolymer',
#  ' alcohol denat',
#  ' aloe barbadensis (aloe vera) leaf juice',
#  ' avobenzone 3% ',
#  ' camelia sinensis',
#  ' cetyl ethylhexanoate',
#  ' hadasei3',
#  ' jojoba oil',
#  ' lauroyl lysine',
#  ' lvmh patent',
#  ' mica',
#  ' tea tree flower/leaf/stem extract',
#  ' vp/va copolymer',
#  ' water ',
#  '(bergamot) fruit oil',
#  '(bilberry) extract',
#  '(evening primrose) oil',
#  '(fragrance)',
#  '(jojoba) seed oil',
#  '(mel) honey',
#  '(microcrystalline cellulose',
#  '(rosemary) leaf extract (rosmarinus officinalis leaf extract)',
#  '1',
#  '1,10decanediol',
#  '1,2 hexanediol',
#  '1,3butylene glycol',
#  '100 percent pure argan oil',
#  '100 percent sugarcanederived squalane',
#  '100% natural abaca leaf fiber',
#  '100% unrefined sclerocraya birrea (marula) kernel oil',
#  '10hydroxydecanoic acid',
#  '10hydroxydecanoic acid ',
#  '15 dimethicone',
# ...
